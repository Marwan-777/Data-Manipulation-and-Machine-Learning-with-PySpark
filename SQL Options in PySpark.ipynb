# %% [markdown]
# # SQL Options in Spark HW
#
# Alirght let's apply what we learned in the lecture to a new dataset!
#
# **But first!**
#
# Let's start with Spark SQL. But first we need to create a Spark Session!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "drive/MyDrive/5. Spark/spark-scripts/section2/Datasets/"

# %%
# !pip install pyspark
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('sparksql').getOrCreate()
spark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 22.3 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=31b382e36cc1b32897592cbbd65bbd391339d31fcaf961b6239a9e2fa35df55f
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://f25133e15bdc:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>sparksql</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Read in our DataFrame for this Notebook
#
# For this notebook we will be using the Google Play Store csv file attached to this lecture. Let's go ahead and read it in.
#
# ### About this dataset
#
# Contains a list of Google Play Store Apps and info about the apps like the category, rating, reviews, size, etc.
#
# **Source:** https://www.kaggle.com/lava18/google-play-store-apps

# %%
df = spark.read.csv(path+'googleplaystore.csv',inferSchema = True, header = True)

# %% [markdown]
# ## First things first
#
# Let's check out the first few lines of the dataframe to see what we are working with

# %%
import pandas as pd
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

df.limit(5).toPandas()
# Out:
#                                                   App        Category Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                 Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN    4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# As well as the schema to make sure all the column types were correctly infered

# %%
df.printSchema()
# Out:
# root
#  |-- App: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Rating: string (nullable = true)
#  |-- Reviews: string (nullable = true)
#  |-- Size: string (nullable = true)
#  |-- Installs: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Price: string (nullable = true)
#  |-- Content Rating: string (nullable = true)
#  |-- Genres: string (nullable = true)
#  |-- Last Updated: string (nullable = true)
#  |-- Current Ver: string (nullable = true)
#  |-- Android Ver: string (nullable = true)

# %% [markdown]
# Looks like we need to edit some of the datatypes. We need to update Rating, Reviews and Price as integer (float for Rating) values for now, since the Size and Installs variables will need a bit more cleaning. Since we haven't been over this yet, I'm going to provide the code for you here so you can get a quick look at how it used (and how often we need it!).
#
# **make sure to change the df name to whatever you named your df**

# %%
from pyspark.sql.types import IntegerType, FloatType
df = df.withColumn("Rating", df["Rating"].cast(FloatType())) \
            .withColumn("Reviews", df["Reviews"].cast(IntegerType())) \
            .withColumn("Price", df["Price"].cast(IntegerType()))
print(df.printSchema())
df.limit(5).toPandas()
# Out:
# root
#  |-- App: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Rating: float (nullable = true)
#  |-- Reviews: integer (nullable = true)
#  |-- Size: string (nullable = true)
#  |-- Installs: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Price: integer (nullable = true)
#  |-- Content Rating: string (nullable = true)
#  |-- Genres: string (nullable = true)
#  |-- Last Updated: string (nullable = true)
#  |-- Current Ver: string (nullable = true)
#  |-- Android Ver: string (nullable = true)
#
# None
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159   19M      10,000+  Free      0       Everyone
# 1      967   14M     500,000+  Free      0       Everyone
# 2    87510  8.7M   5,000,000+  Free      0       Everyone
# 3   215644   25M  50,000,000+  Free      0           Teen
# 4      967  2.8M     100,000+  Free      0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# Looks like that worked! Great! Let's dig in.

# %% [markdown]
# ## 1. Create Tempview
#
# Go ahead and create a tempview of the dataframe so we can work with it in spark sql.

# %%
df.createOrReplaceTempView('view')

# %% [markdown]
# ## 2. Select all apps with ratings above 4.1
#
# Use your tempview to select all apps with ratings above 4.1

# %%
spark.sql('SELECT * FROM view WHERE rating > 4.1').show()
# Out:
# +--------------------+--------------+------+-------+----+-----------+----+-----+--------------+--------------------+------------------+------------------+------------+
# |                 App|      Category|Rating|Reviews|Size|   Installs|Type|Price|Content Rating|              Genres|      Last Updated|       Current Ver| Android Ver|
# +--------------------+--------------+------+-------+----+-----------+----+-----+--------------+--------------------+------------------+------------------+------------+
# |U Launcher Lite –...|ART_AND_DESIGN|   4.7|  87510|8.7M| 5,000,000+|Free|    0|      Everyone|        Art & Design|    August 1, 2018|             1.2.4|4.0.3 and up|
# |Sketch - Draw & P...|ART_AND_DESIGN|   4.5| 215644| 25M|50,000,000+|Free|    0|          Teen|        Art & Design|      June 8, 2018|Varies with device|  4.2 and up|
# |Pixel Draw - Numb...|ART_AND_DESIGN|   4.3|    967|2.8M|   100,000+|Free|    0|      Everyone|Art & Design;Crea...|     June 20, 2018|               1.1|  4.4 and up|
# |Paper flowers ins...|ART_AND_DESIGN|   4.4|    167|5.6M|    50,000+|Free|    0|      Everyone|        Art & Design|    March 26, 2017|               1.0|  2.3 and up|
# |Garden Coloring Book|ART_AND_DESIGN|   4.4|  13791| 33M| 1,000,000+|Free|    0|      Everyone|        Art & Design|September 20, 2017|             2.9.2|  3.0 and up|
# |Kids Paint Free -...|ART_AND_DESIGN|   4.7|    121|3.1M|    10,000+|Free|    0|      Everyone|Art & Design;Crea...|      July 3, 2018|               2.8|4.0.3 and up|
# |Text on Photo - F...|ART_AND_DESIGN|   4.4|  13880| 28M| 1,000,000+|Free|    0|      Everyone|        Art & Design|  October 27, 2017|             1.0.4|  4.1 and up|
# |Name Art Photo Ed...|ART_AND_DESIGN|   4.4|   8788| 12M| 1,000,000+|Free|    0|      Everyone|        Art & Design|     July 31, 2018|            1.0.15|  4.0 and up|
# |Tattoo Name On My...|ART_AND_DESIGN|   4.2|  44829| 20M|10,000,000+|Free|    0|          Teen|        Art & Design|     April 2, 2018|               3.8|  4.1 and up|
# |Mandala Coloring ...|ART_AND_DESIGN|   4.6|   4326| 21M|   100,000+|Free|    0|      Everyone|        Art & Design|     June 26, 2018|             1.0.4|  4.4 and up|
# |3D Color Pixel by...|ART_AND_DESIGN|   4.4|   1518| 37M|   100,000+|Free|    0|      Everyone|        Art & Design|    August 3, 2018|             1.2.3|  2.3 and up|
# |Photo Designer - ...|ART_AND_DESIGN|   4.7|   3632|5.5M|   500,000+|Free|    0|      Everyone|        Art & Design|     July 31, 2018|               3.1|  4.1 and up|
# |350 Diy Room Deco...|ART_AND_DESIGN|   4.5|     27| 17M|    10,000+|Free|    0|      Everyone|        Art & Design|  November 7, 2017|               1.0|  2.3 and up|
# |FlipaClip - Carto...|ART_AND_DESIGN|   4.3| 194216| 39M| 5,000,000+|Free|    0|      Everyone|        Art & Design|    August 3, 2018|             2.2.5|4.0.3 and up|
# |        ibis Paint X|ART_AND_DESIGN|   4.6| 224399| 31M|10,000,000+|Free|    0|      Everyone|        Art & Design|     July 30, 2018|             5.5.4|  4.1 and up|
# |Superheroes Wallp...|ART_AND_DESIGN|   4.7|   7699|4.2M|   500,000+|Free|    0|  Everyone 10+|        Art & Design|     July 12, 2018|           2.2.6.2|4.0.3 and up|
# |Mcqueen Coloring ...|ART_AND_DESIGN|   NaN|     61|7.0M|   100,000+|Free|    0|      Everyone|Art & Design;Acti...|     March 7, 2018|             1.0.0|  4.1 and up|
# |HD Mickey Minnie ...|ART_AND_DESIGN|   4.7|    118| 23M|    50,000+|Free|    0|      Everyone|        Art & Design|      July 7, 2018|             1.1.3|  4.1 and up|
# |Harley Quinn wall...|ART_AND_DESIGN|   4.8|    192|6.0M|    10,000+|Free|    0|      Everyone|        Art & Design|    April 25, 2018|               1.5|  3.0 and up|
# |Colorfit - Drawin...|ART_AND_DESIGN|   4.7|  20260| 25M|   500,000+|Free|    0|      Everyone|Art & Design;Crea...|  October 11, 2017|             1.0.8|4.0.3 and up|
# +--------------------+--------------+------+-------+----+-----------+----+-----+--------------+--------------------+------------------+------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## 3. Now pass your results to an object
# (ie create a spark dataframe)
#
# Select just the App and Rating column where the Category is in the Comic category and the Rating is above 4.5.

# %%
data = spark.sql("select App,rating from view where lower(Category) = 'comics' and rating > 4.5 ")
data.limit(5).toPandas()
# Out:
#                                                                     App  \
# 0                              Manga Master - Best manga & comic reader
# 1  GANMA! - All original stories free of charge for all original comics
# 2                                             Röhrich Werner Soundboard
# 3                                       Unicorn Pokez - Color By Number
# 4                                         Manga - read Thai translation
#
#    rating
# 0     4.6
# 1     4.7
# 2     4.7
# 3     4.8
# 4     4.6

# %% [markdown]
# ## 4. Which category has the most cumulative reviews
#
# Only select the one category with the most reivews.
#
# *Note: will require adding all the review together for each category*

# %%
spark.sql('select Category, sum(reviews) as Total_reviews from view group by category order by sum(reviews) desc').show()
# Out:
# +-------------------+-------------+
# |           Category|Total_reviews|
# +-------------------+-------------+
# |               GAME|   1585422349|
# |      COMMUNICATION|    815462260|
# |             SOCIAL|    621241422|
# |             FAMILY|    410226330|
# |              TOOLS|    273185044|
# |        PHOTOGRAPHY|    213516650|
# |           SHOPPING|    115041222|
# |       PRODUCTIVITY|    114116975|
# |      VIDEO_PLAYERS|    110380188|
# |    PERSONALIZATION|     89346140|
# |             SPORTS|     70830169|
# |   TRAVEL_AND_LOCAL|     62617919|
# |      ENTERTAINMENT|     59178154|
# | NEWS_AND_MAGAZINES|     54400863|
# |          EDUCATION|     39595786|
# | HEALTH_AND_FITNESS|     37891234|
# |MAPS_AND_NAVIGATION|     30557006|
# |BOOKS_AND_REFERENCE|     21959069|
# |            FINANCE|     17550728|
# |            WEATHER|     14604735|
# +-------------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ## 5. Which App has the most reviews?
#
# Display ONLY the top result
#
# Include only the App column and the Reviews column.

# %%
spark.sql('select app,reviews from view order by reviews desc limit 1').toPandas()
# Out:
#         app   reviews
# 0  Facebook  78158306

# %% [markdown]
# ## 5. Select all apps that contain the word 'dating' anywhere in the title
#
# *Note: we did not cover this in the lecture. You'll have to use your SQL knowledge :) Google it if you need to.*

# %%
spark.sql("select * from view where app like '%dating%' ").toPandas()
# Out:
#                                                   App   Category  Rating  \
# 0  Meet, chat & date. Free dating app - Chocolate app     DATING     3.9
# 1           Friend Find: free chat + flirt dating app     DATING     NaN
# 2                               Spine- The dating app     DATING     5.0
# 3       Princess Closet : Otome games free dating sim     FAMILY     4.5
# 4                            happn – Local dating app  LIFESTYLE     4.3
#
#    Reviews                Size     Installs  Type  Price Content Rating  \
# 0     8661                9.5M   1,000,000+  Free      0     Mature 17+
# 1       23                 11M         100+  Free      0     Mature 17+
# 2        5                9.3M         500+  Free      0           Teen
# 3    29495                 56M   1,000,000+  Free      0           Teen
# 4  1118201  Varies with device  10,000,000+  Free      0     Mature 17+
#
#        Genres   Last Updated         Current Ver         Android Ver
# 0      Dating  April 3, 2018              0.1.11          4.0 and up
# 1      Dating  July 31, 2018                 1.0          4.4 and up
# 2      Dating  July 14, 2018                 4.0        4.0.3 and up
# 3  Simulation   May 24, 2018              1.11.0        4.0.3 and up
# 4   Lifestyle  July 24, 2018  Varies with device  Varies with device

# %% [markdown]
# ## 6. Use SQL Transformer to display how many free apps there are in this list

# %%
from pyspark.ml.feature import SQLTransformer

query = SQLTransformer(statement = "select count(*) as Number_of_apps from __THIS__ where type = 'Free' ")

query.transform(df).toPandas()
# Out:
#    Number_of_apps
# 0           10037

# %% [markdown]
# ## 7. What is the most popular Genre?
#
# Which genre appears most often in the dataframe. Show only the top result.

# %%
spark.sql('select category, count(*) from view group by category order by count(*) desc limit 1 ').toPandas()
# Out:
#   category  count(1)
# 0   FAMILY      1972

# %% [markdown]
# ## 8. Select all the apps in the 'Tools' genre that have more than 100 reviews

# %%
spark.sql("select * from view where lower(category) = 'tools' and reviews > 100 ").toPandas()
# Out:
#                                                     App Category  Rating  \
# 0                                     Moto File Manager    TOOLS     4.1
# 1                                                Google    TOOLS     4.4
# 2                                      Google Translate    TOOLS     4.4
# 3                                          Moto Display    TOOLS     4.2
# 4                                        Motorola Alert    TOOLS     4.2
# 5                                       Motorola Assist    TOOLS     4.1
# 6    Cache Cleaner-DU Speed Booster (booster & cleaner)    TOOLS     4.5
# 7                                    Moto Suggestions ™    TOOLS     4.6
# 8                                            Moto Voice    TOOLS     4.1
# 9                                            Calculator    TOOLS     4.3
# 10                                          Device Help    TOOLS     4.2
# 11                                      Account Manager    TOOLS     4.1
# 12                                              myMetro    TOOLS     4.0
# 13                                         File Manager    TOOLS     4.6
# 14                                            My Telcel    TOOLS     3.1
# 15   Calculator - free calculator, multi calculator app    TOOLS     4.6
# 16                                  ASUS Sound Recorder    TOOLS     4.5
# 17                                   iWnn IME for Nexus    TOOLS     3.2
# 18      Samsung Max - Data Savings & Privacy Protection    TOOLS     4.3
# 19                                           ZenUI Help    TOOLS     4.6
# 20   Calculator - free calculator ,multi calculator app    TOOLS     4.4
# 21                           SHAREit - Transfer & Share    TOOLS     4.6
# 22                        ZenUI Keyboard – Emoji, Theme    TOOLS     4.5
# 23      Files Go by Google: Free up space on your phone    TOOLS     4.6
# 24                                       SD card backup    TOOLS     NaN
# 25                                 Nokia mobile support    TOOLS     4.4
# 26    File Manager -- Take Command of Your Files Easily    TOOLS     4.2
# 27                                   Samsung Calculator    TOOLS     4.4
# 28                                                Clear    TOOLS     3.1
# 29                                                Phone    TOOLS     3.6
# 30                                      HTC Lock Screen    TOOLS     4.1
# 31                         Gboard - the Google Keyboard    TOOLS     4.2
# 32                                  Google Korean Input    TOOLS     3.5
# 33                                     AT&T Smart Wi-Fi    TOOLS     3.9
# 34        Sound Recorder: Recorder & Voice Changer Free    TOOLS     3.9
# 35                              Remote Link (PC Remote)    TOOLS     4.5
# 36                                      HTC Sense Input    TOOLS     3.4
# 37                Share Music & Transfer Files - Xender    TOOLS     4.4
# 38                                            App vault    TOOLS     3.4
# 39                           TouchPal Keyboard for vivo    TOOLS     4.3
# 40                                  Google Assistant Go    TOOLS     3.7
# 41                                              My love    TOOLS     3.5
# 42                                            DuraSpeed    TOOLS     3.8
# 43                                   HTC Sense Input-CA    TOOLS     3.1
# 44                                   HTC Sense Input-AR    TOOLS     3.8
# 45                                  Digital Alarm Clock    TOOLS     4.2
# 46                                     Alarm Clock Free    TOOLS     4.0
# 47                                 Puzzle Alarm Clock ⏰    TOOLS     4.3
# 48                                          Alarm Clock    TOOLS     4.3
# 49                         I Can't Wake Up! Alarm Clock    TOOLS     4.5
# 50                              High-Powered Flashlight    TOOLS     4.5
# 51                     Brightest Flashlight - LED Light    TOOLS     4.5
# 52                                       LED Flashlight    TOOLS     4.4
# 53                                Tiny Flashlight + LED    TOOLS     4.4
# 54                               Flashlight & LED Torch    TOOLS     4.3
# 55                                     Color Flashlight    TOOLS     4.2
# 56                                           Flashlight    TOOLS     4.7
# 57                         CM Flashlight (Compass, SOS)    TOOLS     4.4
# 58                                    Flashlight HD LED    TOOLS     4.3
# 59                         Flashlight - Torch LED Light    TOOLS     4.4
# 60                               Super Flashlight + LED    TOOLS     4.3
# 61                             Brightest LED Flashlight    TOOLS     4.5
# 62                          Brightest Flashlight Free ®    TOOLS     4.7
# 63                        Fraction Calculator Plus Free    TOOLS     4.5
# 64                                 Calculator Plus Free    TOOLS     4.6
# 65                       CALCU™ Stylish Calculator Free    TOOLS     4.7
# 66                      Mobi Calculator free & AD free!    TOOLS     4.6
# 67                       Calculator with Percent (Free)    TOOLS     4.8
# 68                                  Graphing Calculator    TOOLS     3.9
# 69                                       Unit Converter    TOOLS     4.5
# 70                                        Calculator ++    TOOLS     4.6
# 71                                  MyScript Calculator    TOOLS     4.5
# 72                          ConvertPad - Unit Converter    TOOLS     4.4
# 73                                   Unit Converter Pro    TOOLS     4.5
# 74                                   Classic Calculator    TOOLS     4.0
# 75                           Scientific Calculator Free    TOOLS     4.3
# 76                         weight conversion calculator    TOOLS     4.0
# 77                                       Age Calculator    TOOLS     4.4
# 78                                         EzCalculator    TOOLS     4.1
# 79                             SuperVPN Free VPN Client    TOOLS     4.3
# 80                                          Hideman VPN    TOOLS     4.1
# 81                                      Fast Secure VPN    TOOLS     4.3
# 82                        Free & Premium VPN - FinchVPN    TOOLS     4.2
# 83       Hotspot Shield Free VPN Proxy & Wi-Fi Security    TOOLS     4.2
# 84         OpenVPN Connect – Fast & Safe SSL VPN Client    TOOLS     4.2
# 85     VPN - Fast, Secure & Unlimited WiFi with VyprVPN    TOOLS     4.2
# 86       FREEDOME VPN Unlimited anonymous Wifi Security    TOOLS     4.3
# 87                          SurfEasy Secure Android VPN    TOOLS     4.5
# 88                                       TunnelBear VPN    TOOLS     4.4
# 89   VPN Free - Betternet Hotspot VPN & Private Browser    TOOLS     4.5
# 90                         Gboard - the Google Keyboard    TOOLS     4.2
# 91                                 Smart Keyboard Trial    TOOLS     4.1
# 92       Emoji keyboard - Cute Emoticons, GIF, Stickers    TOOLS     4.4
# 93           GO Keyboard - Cute Emojis, Themes and GIFs    TOOLS     4.5
# 94                             Google Handwriting Input    TOOLS     4.3
# 95                                        Wifi Analyzer    TOOLS     4.4
# 96                                  Network Signal Info    TOOLS     4.1
# 97                                   Speedtest by Ookla    TOOLS     4.4
# 98                              osmino Wi-Fi: free WiFi    TOOLS     4.2
# 99                                    WiFi Overview 360    TOOLS     4.1
# 100                                          Speedcheck    TOOLS     4.6
# 101                           Internet Speed Meter Lite    TOOLS     4.5
# 102                                      Wifi Inspector    TOOLS     4.3
# 103                                      WiFi Automatic    TOOLS     4.1
# 104                              NETGEAR WiFi Analytics    TOOLS     4.1
# 105                                  Keypad Lock Screen    TOOLS     4.2
# 106                             photo keypad lockscreen    TOOLS     4.1
# 107                     CM Locker - Security Lockscreen    TOOLS     4.6
# 108                            Solo Locker (DIY Locker)    TOOLS     4.5
# 109                                         Lock Screen    TOOLS     4.0
# 110                                    ZERO Lock Screen    TOOLS     3.5
# 111                               AppLock - Fingerprint    TOOLS     4.4
# 112                                             Applock    TOOLS     4.4
# 113                         Smart AppLock (App Protect)    TOOLS     4.4
# 114                                 Screen Off and Lock    TOOLS     4.1
# 115                                         Screen Lock    TOOLS     4.2
# 116                                          Flashlight    TOOLS     4.5
# 117                                    Google Translate    TOOLS     4.4
# 118                                  B-BLE(BLE4.0 Scan)    TOOLS     3.8
# 119  VPN Free - Betternet Hotspot VPN & Private Browser    TOOLS     4.5
# 120                             Servers Ultimate Pack B    TOOLS     4.3
# 121             Clean Master- Space Cleaner & Antivirus    TOOLS     4.7
# 122            Screen Lock - with Fingerprint Simulator    TOOLS     3.7
# 123                               Tuner - gStrings Free    TOOLS     4.5
# 124                        Lookout Security & Antivirus    TOOLS     4.4
# 125                       Video Downloader for Facebook    TOOLS     4.6
# 126                                  FlashLight F.Light    TOOLS     4.3
# 127                       F-Secure KEY Password manager    TOOLS     4.2
# 128                                       F-Secure SAFE    TOOLS     4.3
# 129                                    F-Secure AV Test    TOOLS     4.5
# 130                            F-Secure Mobile Security    TOOLS     4.2
# 131                        Gboard - the Google Keyboard    TOOLS     4.2
# 132                                              Google    TOOLS     4.4
# 133                                 Google Now Launcher    TOOLS     4.2
# 134                      G Cloud Apps Backup Key * root    TOOLS     4.5
# 135                                      G-NetTrack Pro    TOOLS     4.3
# 136                      Speedometer with G-FORCE meter    TOOLS     3.8
# 137                                   Car G-Force Meter    TOOLS     4.2
# 138                          HSPA+ Tweaker (3G booster)    TOOLS     4.3
# 139           DNS Changer - BEST (Gprs/Edge/3G/H/H+/4G)    TOOLS     4.3
# 140                                      Force LTE Only    TOOLS     4.1
# 141                               Mobile Number Tracker    TOOLS     3.9
# 142                                     I Screen Dialer    TOOLS     4.1
# 143                                             J Touch    TOOLS     4.6
# 144                                     Smart TV Remote    TOOLS     3.5
# 145                                K keyboard - Myanmar    TOOLS     4.8
# 146                           M Notifier for M Launcher    TOOLS     4.2
# 147         O Launcher 8.0 for Android™ O Oreo Launcher    TOOLS     4.4
# 148                  AC Remote for O General - NOW FREE    TOOLS     3.7
# 149                                          O Launcher    TOOLS     4.3
# 150        O Multiple - App Cloner, Duals APP, tarallel    TOOLS     3.9
# 151  Super P Launcher for Android P 9.0 launcher, theme    TOOLS     4.4
# 152         Volume Slider Like Android P Volume Control    TOOLS     4.1
# 153         P9 Launcher - Android™ 9.0 P Launcher Style    TOOLS     4.3
# 154                                  Android P Rotation    TOOLS     4.5
# 155                     Android P Launcher 9.0 launcher    TOOLS     4.0
# 156                                       Q-See QC View    TOOLS     3.1
# 157                                    Q Remote Control    TOOLS     3.8
# 158                                                 myQ    TOOLS     3.6
# 159                                      QR Code Reader    TOOLS     4.0
# 160                                       Q-See QT View    TOOLS     3.6
# 161                                                  .R    TOOLS     4.5
# 162                          SHAREit - Transfer & Share    TOOLS     4.6
# 163     360 Security - Free Antivirus, Booster, Cleaner    TOOLS     4.6
# 164  S Player - Lightest and Most Powerful Video Player    TOOLS     4.6
# 165                         Samsung Smart Switch Mobile    TOOLS     4.3
# 166  S S9 Launcher - Galaxy S8/S9 Launcher, theme, cool    TOOLS     4.4
# 167                                        S Pen Keeper    TOOLS     3.8
# 168                                            T-Mobile    TOOLS     4.3
# 169                           T-Mobile Visual Voicemail    TOOLS     3.6
# 170                                    I Can't Wake Up!    TOOLS     4.7
# 171                                     AT&T FamilyMap®    TOOLS     3.5
# 172                                Don't touch my phone    TOOLS     3.8
# 173                                              U-Scan    TOOLS     3.4
# 174        Parallel U - App Cloner, Duals APP, tarallel    TOOLS     4.1
# 175                                             U Guard    TOOLS     3.0
# 176                       Ace Screen Recorder w facecam    TOOLS     4.2
# 177                                 WIFI WPS WPA TESTER    TOOLS     4.3
# 178   App Lock: Locker w/ fingerprint, Parental Control    TOOLS     4.5
# 179                    Open in WhatsApp (click to chat)    TOOLS     4.2
# 180                                              WPSApp    TOOLS     4.4
# 181                    X-VPN - Free Unlimited VPN Proxy    TOOLS     4.5
# 182               Share Music & Transfer Files - Xender    TOOLS     4.4
# 183  Phone X Launcher, OS 11 iLauncher & Control Center    TOOLS     4.2
# 184                     Lock Screen Phone X Style OS 11    TOOLS     4.4
# 185       Control Center iOS 11 - Phone X Control Panel    TOOLS     4.1
# 186                                X-plore File Manager    TOOLS     4.6
# 187                                        Flashlight X    TOOLS     4.6
# 188                                      iSwipe Phone X    TOOLS     4.7
# 189                                   X Home Bar - Free    TOOLS     4.6
# 190                          [ROOT] X Privacy Installer    TOOLS     4.2
# 191                                      X-Plane to GPS    TOOLS     4.2
# 192       Control Center iOS 11 - Phone X notifications    TOOLS     4.3
# 193                         Antivirus & Mobile Security    TOOLS     4.6
# 194                                 Flashlight Ultimate    TOOLS     4.6
# 195   Avast Mobile Security 2018 - Antivirus & App Lock    TOOLS     4.5
# 196                                           ZArchiver    TOOLS     4.5
# 197                      Zapya - File Transfer, Sharing    TOOLS     4.6
# 198                                               CPU-Z    TOOLS     4.5
# 199                                       Moto Z Market    TOOLS     2.2
# 200                                    ZArchiver Donate    TOOLS     4.8
# 201                                  AB Screen Recorder    TOOLS     4.2
# 202                         Universal AC Remote Control    TOOLS     3.8
# 203                               Smart Air Conditioner    TOOLS     3.3
# 204                                   AC Remote Control    TOOLS     3.3
# 205                      Air conditioner remote control    TOOLS     3.4
# 206                          A/C Air Conditioner Remote    TOOLS     3.4
# 207                          Smart Air Conditioner(CAC)    TOOLS     3.2
# 208                             Carrier Air Conditioner    TOOLS     2.5
# 209                                   AC Troubleshooter    TOOLS     4.7
# 210                            AC remote control mobile    TOOLS     3.9
# 211                      AC Remote for Haier - NOW FREE    TOOLS     3.9
# 212                     AC Remote for Daikin - NOW FREE    TOOLS     3.5
# 213                        A/C Universal Remote Control    TOOLS     3.1
# 214                         AC Remote for LG - NOW FREE    TOOLS     3.7
# 215                             Plug-in app (System AC)    TOOLS     3.6
# 216                      AC Remote for Midea - NOW FREE    TOOLS     4.0
# 217                                   Ac remote control    TOOLS     3.7
# 218     Mi Remote controller - for TV, STB, AC and more    TOOLS     4.1
# 219                                    AC Remote For LG    TOOLS     3.0
# 220                      AC Remote for Sharp - NOW FREE    TOOLS     3.7
# 221                    AC Remote for Samsung - NOW FREE    TOOLS     3.7
# 222                    AC Remote for Carrier - NOW FREE    TOOLS     3.7
# 223       AC & TV, DVD, Set Top Box - Remote control IR    TOOLS     3.6
# 224                                   ac remote control    TOOLS     3.7
# 225                                AppBrain Ad Detector    TOOLS     3.7
# 226                      AdClear Ad blocker for Samsung    TOOLS     4.2
# 227                             Adguard Content Blocker    TOOLS     4.1
# 228                                         Ad Detector    TOOLS     3.8
# 229                                         FVD Ad-Free    TOOLS     4.4
# 230                                         Anti Adware    TOOLS     3.9
# 231    Vpn Hosts (ad blocker & no root & support ipv6 )    TOOLS     4.4
# 232                        Ad Block REMOVER - NEED ROOT    TOOLS     3.3
# 233                        Photo Compress 2.0 - Ad Free    TOOLS     4.1
# 234                          RAM Cleanup Ad-Free Option    TOOLS     4.4
# 235                             Emo Ads Blocker Browser    TOOLS     3.4
# 236                                   Apps Ads Detector    TOOLS     3.5
# 237                     Mobi Calculator free & AD free!    TOOLS     4.6
# 238                                 AppFinder by AppTap    TOOLS     2.0
# 239                                             AppLock    TOOLS     4.4
# 240                         ParaTek Ai Speech generator    TOOLS     3.6
# 241                                         Where Am I?    TOOLS     4.2
# 242                                          AP Manager    TOOLS     4.0
# 243                                               UniFi    TOOLS     4.7
# 244                 Ap Video Downloader for fb New 2018    TOOLS     4.2
# 245                      HotSpot Tethering Free/WiFi AP    TOOLS     3.9
# 246                                        APN Settings    TOOLS     3.7
# 247                                  QR BARCODE SCANNER    TOOLS     3.8
# 248                ARuler - AR Ruler app, Measure tools    TOOLS     4.3
# 249                                   Image 2 Wallpaper    TOOLS     4.3
# 250                                        Powershop AU    TOOLS     4.0
# 251             AVG AntiVirus 2018 for Android Security    TOOLS     4.5
# 252                                            AV Tools    TOOLS     4.4
# 253    Remote for Onkyo AV Receivers & Smart TV/Blu-Ray    TOOLS     3.7
# 254                                        LG AV REMOTE    TOOLS     3.4
# 255                       Norton Security and Antivirus    TOOLS     4.6
# 256         Remote For Pioneer AV Receivers and Blu-Ray    TOOLS     3.4
# 257  Kaspersky Mobile Antivirus: AppLock & Web Security    TOOLS     4.7
# 258                          Bitdefender Antivirus Free    TOOLS     4.5
# 259     Avast Cleanup & Boost, Phone Cleaner, Optimizer    TOOLS     4.5
# 260                              Analog Clock AW Plus-7    TOOLS     4.2
# 261                                   Analog Clock AW-7    TOOLS     4.3
# 262                                          Watch AW-7    TOOLS     4.2
# 263                                  Digital Clock AW-7    TOOLS     4.1
# 264                       Analog and Digital Clock AW-7    TOOLS     4.0
# 265                            Square Analog Clock AW-7    TOOLS     4.2
# 266                          Display Phone Screen On TV    TOOLS     3.6
# 267                                   AZ REMOTE CONTROL    TOOLS     2.1
# 268  Remote for Samsung TV & BluRay Players (Read Desc)    TOOLS     3.3
# 269      Remote for Sony TV & Sony Blu-Ray Players MyAV    TOOLS     3.4
# 270                      Remote for Panasonic TV+BD+AVR    TOOLS     3.7
# 271                               Unseen - No Last Seen    TOOLS     4.4
# 272                                             BF-Calc    TOOLS     3.9
# 273                                    Droid PRoCon BF3    TOOLS     3.5
# 274                                  HTC Sense Input-BG    TOOLS     2.7
# 275                                HTC Sense Input - BG    TOOLS     3.3
# 276                                            ScorePal    TOOLS     4.5
# 277                                         BusyBox Pro    TOOLS     4.7
# 278                                             VIVA BH    TOOLS     4.0
# 279                             All Language Translator    TOOLS     4.0
# 280                              Virtual DJ Sound Mixer    TOOLS     4.2
# 281                             Metal Detector Pro 2015    TOOLS     3.6
# 282                                        Power Widget    TOOLS     4.2
# 283                                    Service Disabler    TOOLS     4.3
# 284                          BM Online OEC Verification    TOOLS     4.1
# 285                                         BQ Services    TOOLS     3.7
# 286                                     Software Update    TOOLS     4.4
# 287                                  System Update Free    TOOLS     4.3
# 288                              Free antivirus and VPN    TOOLS     4.3
# 289                                      Simple Gallery    TOOLS     4.5
# 290                        Next Portuguese(BR) Langpack    TOOLS     4.3
# 291                                         BS Battery+    TOOLS     4.3
# 292                       CABLE SIZE CALCULATOR BS 7671    TOOLS     3.9
# 293                                      BTNotification    TOOLS     3.9
# 294                                    Little Magnet BT    TOOLS     4.6
# 295                                         BT Notifier    TOOLS     2.5
# 296                                Little Magnet BT Pro    TOOLS     4.6
# 297                      Bt Notifier -Smartwatch notice    TOOLS     2.8
# 298                                       BT Controller    TOOLS     3.9
# 299                                Mediatek SmartDevice    TOOLS     3.6
# 300                                   LG BT Reader Plus    TOOLS     3.7
# 301                             Battery Notifier Pro BT    TOOLS     4.7
# 302                            Battery Notifier BT Free    TOOLS     4.5
# 303                                      VictronConnect    TOOLS     3.8
# 304      Bixby Button Remapper - bxActions Pro / Coffee    TOOLS     3.9
# 305                   Bixby Button Remapper - bxActions    TOOLS     4.3
# 306                      Limbo PC Emulator QEMU ARM x86    TOOLS     4.2
# 307                                Project Fi by Google    TOOLS     4.6
# 308                                              Bubble    TOOLS     4.5
# 309                                       CA Mobile OTP    TOOLS     3.3
# 310                                              CA DMV    TOOLS     4.2
# 311                                CB Frequencies FREE!    TOOLS     3.1
# 312                                    Frequencies Free    TOOLS     3.5
# 313                                          CBRadioTab    TOOLS     3.9
# 314                                        Antenna Tool    TOOLS     4.2
# 315                                    Disc Label Print    TOOLS     3.0
# 316                                            CCleaner    TOOLS     4.4
# 317                       Terminal Emulator for Android    TOOLS     4.4
# 318                                            CF.lumen    TOOLS     4.4
# 319                                        CF-Bench Pro    TOOLS     4.6
# 320                                            CF-Bench    TOOLS     4.4
# 321                                              CF cal    TOOLS     4.3
# 322                                   CG Shikshak Mitan    TOOLS     4.1
# 323                                      Battery HD Pro    TOOLS     4.7
# 324                              Automagic * Automation    TOOLS     4.7
# 325                               FlashLight HD LED Pro    TOOLS     4.7
# 326  Security Master - Antivirus, VPN, AppLock, Booster    TOOLS     4.7
# 327                     CM Locker - Security Lockscreen    TOOLS     4.6
# 328               Clean Master Lite - For Low-End Phone    TOOLS     4.6
# 329   CM Security Open VPN - Free, fast unlimited proxy    TOOLS     4.6
# 330                        CM Security Lite - Antivirus    TOOLS     4.6
# 331                        CM Flashlight (Compass, SOS)    TOOLS     4.4
# 332                                             CM Apps    TOOLS     3.8
# 333                                          CM AppLock    TOOLS     4.1
# 334                                     Ruler(cm, inch)    TOOLS     3.4
# 335                        AppLock - Fingerprint Unlock    TOOLS     4.5
# 336  Battery Doctor-Battery Life Saver & Battery Cooler    TOOLS     4.5
# 337   Speed Booster - Ram, Battery & Game Speed Booster    TOOLS     4.7
# 338                                     CM FILE MANAGER    TOOLS     4.4
# 339                       Height Converter feet-inch cm    TOOLS     4.2
# 340                      CM Secure Browser (Authorized)    TOOLS     4.2
# 341                                            Ruler cm    TOOLS     3.6
# 342                         CM AppLock Fingerprint 2018    TOOLS     4.4
# 343        m, cm, mm to yard, feet, inch converter tool    TOOLS     4.3
# 344                               CM S Pen Add-on(ROOT)    TOOLS     3.6
# 345                                               Ruler    TOOLS     4.5
# 346                               Inches to Centimeters    TOOLS     3.6
# 347             Speed Test - WiFi / Cellular speed test    TOOLS     4.1
# 348    Remote | Fire TV | Android TV | KODI | CetusPlay    TOOLS     4.4
# 349                     Poke Genie - Safe IV Calculator    TOOLS     4.7
# 350                       IV Calc CP Calculator Toolkit    TOOLS     4.2
# 351                                               gCMOB    TOOLS     4.2
# 352                       Evolve CP Calc. for PokemonGo    TOOLS     3.9
# 353                                            Calcy IV    TOOLS     4.8
# 354                              Webmail web mobile app    TOOLS     2.3
# 355                      Battle Result Predictor for CR    TOOLS     4.2
# 356                                 Deck Advisor for CR    TOOLS     4.1
# 357                                 Card Creator for CR    TOOLS     4.4
# 358                                Deck Analyzer for CR    TOOLS     4.2
# 359                               Deck Simulator for CR    TOOLS     3.4
# 360                      Counter Deck Calculator for CR    TOOLS     4.1
# 361                                       CR Calculator    TOOLS     4.3
# 362                             DCUO|CR Calculator Lite    TOOLS     4.0
# 363                                JavaScript Editor CR    TOOLS     3.9
# 364                      Chest Tracker for Clash Royale    TOOLS     4.3
# 365                                      Java Editor CR    TOOLS     3.8
# 366                                    Helper for CS:GO    TOOLS     4.4
# 367                            Remote CT - Smart Remote    TOOLS     3.5
# 368                                   HTC Transfer Tool    TOOLS     4.3
# 369  CV Maker for Job Applications:Photo Resume Builder    TOOLS     4.0
# 370  Easy Resume Builder, Resume help, Curriculum vitae    TOOLS     4.3
# 371                                    Cx File Explorer    TOOLS     4.7
# 372                            Secret Codes For Android    TOOLS     3.6
# 373                                     CZ File Manager    TOOLS     2.2
# 374                          CZ-Cyberon Voice Commander    TOOLS     3.8
# 375                               What is my IP address    TOOLS     4.5
# 376   Master for Minecraft(Pocket Edition)-Mod Launcher    TOOLS     4.6
# 377                  Translate: text & voice translator    TOOLS     4.3
# 378                                  The Zueira's Voice    TOOLS     4.7
# 379                                 Battery Calibration    TOOLS     4.4
# 380                         FVD - Free Video Downloader    TOOLS     4.0
# 381                        Download Manager for Android    TOOLS     4.1
# 382                                    SQLite DB Reader    TOOLS     3.6
# 383                                          DB Browser    TOOLS     3.3
# 384                                         Sound Meter    TOOLS     4.7
# 385                                dB Sound Level Meter    TOOLS     3.9
# 386  DB Sound Meter: Measure Noise Level- Decibel Meter    TOOLS     4.3
# 387   dB Meter - measure sound & noise level in Decibel    TOOLS     4.6
# 388                              DB TOS - Pocket Helper    TOOLS     4.2
# 389                                               SW-DB    TOOLS     4.5
# 390                              DC Universe Online Map    TOOLS     4.1
# 391                        APUS File Manager (Explorer)    TOOLS     4.1
# 392                            Easy Language Translator    TOOLS     4.3
# 393                                  Satellite Director    TOOLS     4.1
# 394                                       Digital Falak    TOOLS     4.7
# 395                        PDF Reader – PDF Editor 2018    TOOLS     4.1
# 396                                         Digoo·Cloud    TOOLS     4.1
# 397                           DiskDigger photo recovery    TOOLS     4.2
# 398                             Automatic Call Recorder    TOOLS     4.3
# 399                                    Virtual DJ Mixer    TOOLS     4.2
# 400                                 Mix Virtual DJ 2018    TOOLS     4.2
# 401                       Advanced Download Manager Pro    TOOLS     4.7
# 402                           Advanced Download Manager    TOOLS     4.5
# 403                      GetThemAll Any File Downloader    TOOLS     4.2
# 404                        Downloader & Private Browser    TOOLS     4.3
# 405                                  Download All Files    TOOLS     3.8
# 406                           Download Accelerator Plus    TOOLS     4.2
# 407                                    Download Manager    TOOLS     3.8
# 408                               Fast Download Manager    TOOLS     4.0
# 409                Turbo Download Manager (and Browser)    TOOLS     4.0
# 410                                     Download Blazer    TOOLS     3.9
# 411                   Download Manager For Android Free    TOOLS     4.0
# 412                                    Turbo Downloader    TOOLS     3.9
# 413                      Advanced Download Manager Holo    TOOLS     4.4
# 414                                  G-Download Manager    TOOLS     4.1
# 415                      TorrDroid - Torrent Downloader    TOOLS     4.7
# 416                     Download Manager - File & Video    TOOLS     3.9
# 417                             File Viewer for Android    TOOLS     4.1
# 418                       EasyNote Notepad | To Do List    TOOLS     4.3
# 419                       Download Instant DP (Full HD)    TOOLS     4.3
# 420                             Anti-virus Dr.Web Light    TOOLS     4.5
# 421   dr.fone - Recovery & Transfer wirelessly & Backup    TOOLS     3.7
# 422     Dr. Battery - Fast Charger - Super Cleaner 2018    TOOLS     4.5
# 423   Dr. Safety - Antivirus, Booster, Cleaner, AppLock    TOOLS     4.4
# 424                               Dr.Web Security Space    TOOLS     4.5
# 425                      Dr. Booster - Boost Game Speed    TOOLS     4.4
# 426                                           DS finder    TOOLS     4.0
# 427                                              DS get    TOOLS     3.4
# 428                                            DS cloud    TOOLS     3.2
# 429                                           DS router    TOOLS     3.8
# 430                        Deep Sleep Battery Saver Pro    TOOLS     3.9
# 431                            Deep Sleep Battery Saver    TOOLS     4.1
# 432                                       DS Flashlight    TOOLS     4.0
# 433                       WhatsVPN - Unlimited Free VPN    TOOLS     4.7
# 434  Cache Cleaner-DU Speed Booster (booster & cleaner)    TOOLS     4.5
# 435   DU Battery Saver - Battery Charger & Battery Life    TOOLS     4.5
# 436     DU Antivirus Security - Applock & Privacy Guard    TOOLS     4.6
# 437     DU Cleaner – Memory cleaner & clean phone cache    TOOLS     4.5
# 438                                         DU Security    TOOLS     4.4
# 439                         DU Browser Mini(Small&Fast)    TOOLS     4.2
# 440     Lock Screen - DU Locker & Lock screen wallpaper    TOOLS     4.5
# 441                           DU Emoji Keyboard（Simeji）    TOOLS     4.3
# 442     DU Flashlight - Brightest LED & Flashlight Free    TOOLS     4.3
# 443                       Upgrade for Android DU Master    TOOLS     3.6
# 444             GO Security－AntiVirus, AppLock, Booster    TOOLS     4.7
# 445                       iCam - Webcam Video Streaming    TOOLS     3.7
# 446                                            SportCAM    TOOLS     3.2
# 447                                             DW VMAX    TOOLS     3.4
# 448                     Digi Dex for DW Next Order @PS4    TOOLS     4.2
# 449                                           edp re:dy    TOOLS     3.0
# 450                              Hidden Camera Detector    TOOLS     3.9
# 451                                     3G/4G Config Dz    TOOLS     4.2
# 452                                Files To SD Card Pro    TOOLS     4.2
# 453                                  My Ooredoo Algeria    TOOLS     4.2
# 454                                              DZ sim    TOOLS     4.4
# 455                      3G to 4G Converter - Simulator    TOOLS     4.2
# 456                          Tamilnadu Electricity Info    TOOLS     3.6
# 457                      energyly (TNEB,BESCOM,MH,DL..)    TOOLS     3.9
# 458                                TN Patta, Chitta, EC    TOOLS     4.1
# 459                             TN Patta Chitta EC Info    TOOLS     4.2
# 460                                     Code on the egg    TOOLS     3.9
# 461                      Silence Premium Do Not Disturb    TOOLS     4.5
# 462                                       SIM Card Info    TOOLS     4.1
# 463                                      The translator    TOOLS     4.5
# 464                        Trazado de tuberia El Tubero    TOOLS     4.5
# 465      Instabridge - Free WiFi Passwords and Hotspots    TOOLS     4.4
# 466                       ai.type keyboard Plus + Emoji    TOOLS     4.5
# 467                                     Keyboard ManMan    TOOLS     4.4
# 468                                HTC Sense Input - EN    TOOLS     4.3
# 469                                      Bluetooth Pair    TOOLS     3.5
# 470                                       ES App Locker    TOOLS     4.3
# 471                                    ES File Explorer    TOOLS     4.1
# 472                              ES Dark Theme for free    TOOLS     4.2
# 473                                    ES Classic Theme    TOOLS     4.3
# 474                                       ES Holo Theme    TOOLS     4.3
# 475                      ES Summer Chill Theme for Free    TOOLS     4.3
# 476           OpenGL ES Extensions - The OpenGL Utility    TOOLS     4.2
# 477                                      OpenGL-ES Info    TOOLS     4.3
# 478                                HTC Sense Input - ES    TOOLS     4.3
# 479                                                 RAR    TOOLS     4.4
# 480  File Manager by Xiaomi: release file storage space    TOOLS     4.8
# 481                                   Moto File Manager    TOOLS     4.1
# 482                                        Epson iPrint    TOOLS     4.1
# 483                                              Tasker    TOOLS     4.6
# 484                                            EdiRange    TOOLS     3.0
# 485                             Advanced EX for HYUNDAI    TOOLS     2.7
# 486     Ex Explorer : Dual view exproler / file manager    TOOLS     3.9
# 487                                 Advanced EX for KIA    TOOLS     3.3
# 488                              Advanced EX for NISSAN    TOOLS     2.9
# 489                                Advanced EX for FIAT    TOOLS     3.5
# 490                             Advanced EX for RENAULT    TOOLS     2.8
# 491                                          Papyrus Ex    TOOLS     4.6
# 492                                           Third Eye    TOOLS     4.4
# 493                             Hey That's Pretty Good!    TOOLS     4.6
# 494                      EZ Cleaner - Booster Optimizer    TOOLS     4.4
# 495                                        EZ Bluetooth    TOOLS     4.2
# 496                               EZ-GUI Ground Station    TOOLS     4.7
# 497                                    EZ App Installer    TOOLS     4.1
# 498                                HTC Sense Input - FA    TOOLS     4.6
# 499                                      Farsi Keyboard    TOOLS     4.3
# 500                       Authy 2-Factor Authentication    TOOLS     4.3
# 501                           Flash Light on Call & SMS    TOOLS     4.1
# 502                                    Mini for fb lite    TOOLS     4.0
# 503        Video Downloader For FB: Save FB Videos 2018    TOOLS     4.3
# 504                               Video Download For FB    TOOLS     4.3
# 505                      Download Facebook Photo Albums    TOOLS     4.0
# 506                            FD Shift Calendar Widget    TOOLS     4.1
# 507                                           FG Finder    TOOLS     NaN
# 508                                            My Truck    TOOLS     2.5
# 509                                            FiSwitch    TOOLS     4.8
# 510                                         Signal Info    TOOLS     4.6
# 511   Signal Spy - Monitor Signal Strength & Data Usage    TOOLS     4.4
# 512                               LG Hi-Fi Plus Manager    TOOLS     3.5
# 513                                       [root] Pry-Fi    TOOLS     3.9
# 514                             Wi-Fi Rabbit Unlock Key    TOOLS     4.5
# 515                             Wi-Fi settings shortcut    TOOLS     4.1
# 516                                        Wi-Fi Master    TOOLS     4.5
# 517                             osmino Wi-Fi: free WiFi    TOOLS     4.2
# 518                                    Wi-Fi Visualizer    TOOLS     3.9
# 519                  Kernel Manager for Franco Kernel ✨    TOOLS     4.8
# 520                               FK Crvena Zvezda Izzy    TOOLS     4.8
# 521                                         Florida 511    TOOLS     3.2
# 522                                     Fo File Manager    TOOLS     4.5
# 523                         Fon WiFi App – WiFi Connect    TOOLS     4.1
# 524   MOD-MASTER for Minecraft PE (Pocket Edition) Free    TOOLS     4.2
# 525                                  Draw with FP sDraw    TOOLS     4.3
# 526                            Fingerprint Quick Action    TOOLS     4.2
# 527                             Finger Scanner Gestures    TOOLS     4.2
# 528                        Fisher-Price® Smart Connect™    TOOLS     2.7
# 529                       Fingerprint Lock Screen Prank    TOOLS     4.1
# 530                              FreedomPop Diagnostics    TOOLS     2.9
# 531                                       ChopAssistant    TOOLS     4.2
# 532                            Reindeer VPN - Proxy VPN    TOOLS     4.2
# 533    Inf VPN - Global Proxy & Unlimited Free WIFI VPN    TOOLS     4.7
# 534                                           FR Roster    TOOLS     4.1
# 535                                HTC Sense Input - FR    TOOLS     4.0
#
#       Reviews                Size        Installs  Type  Price Content Rating  \
# 0       38655                5.9M     10,000,000+  Free    0.0       Everyone
# 1     8033493  Varies with device  1,000,000,000+  Free    0.0       Everyone
# 2     5745093  Varies with device    500,000,000+  Free    0.0       Everyone
# 3       18239  Varies with device     10,000,000+  Free    0.0       Everyone
# 4       24199                3.9M     50,000,000+  Free    0.0       Everyone
# 5       37333  Varies with device     50,000,000+  Free    0.0       Everyone
# 6    12759663                 15M    100,000,000+  Free    0.0       Everyone
# 7         308                4.3M      1,000,000+  Free    0.0       Everyone
# 8       33216  Varies with device     10,000,000+  Free    0.0       Everyone
# 9       40770  Varies with device    100,000,000+  Free    0.0       Everyone
# 10      28860  Varies with device    100,000,000+  Free    0.0       Everyone
# 11      76604  Varies with device    100,000,000+  Free    0.0       Everyone
# 12      26189                5.3M     10,000,000+  Free    0.0       Everyone
# 13     739329  Varies with device     50,000,000+  Free    0.0       Everyone
# 14      45838                 16M     50,000,000+  Free    0.0       Everyone
# 15      25592                7.5M     10,000,000+  Free    0.0       Everyone
# 16      34126  Varies with device     10,000,000+  Free    0.0       Everyone
# 17       2394  Varies with device      5,000,000+  Free    0.0       Everyone
# 18     330468  Varies with device     10,000,000+  Free    0.0       Everyone
# 19     136874  Varies with device     10,000,000+  Free    0.0       Everyone
# 20       1236                5.8M        100,000+  Free    0.0       Everyone
# 21    7790693                 17M    500,000,000+  Free    0.0       Everyone
# 22     537554  Varies with device     10,000,000+  Free    0.0       Everyone
# 23     315585                8.5M     10,000,000+  Free    0.0       Everyone
# 24        142  Varies with device      1,000,000+  Free    0.0       Everyone
# 25      12215                9.1M      5,000,000+  Free    0.0       Everyone
# 26     127223                7.6M     10,000,000+  Free    0.0       Everyone
# 27       9602                2.5M    100,000,000+  Free    0.0       Everyone
# 28      24151                 15M     10,000,000+  Free    0.0       Everyone
# 29      45483  Varies with device     10,000,000+  Free    0.0       Everyone
# 30      28250  Varies with device     10,000,000+  Free    0.0       Everyone
# 31    1859115  Varies with device    500,000,000+  Free    0.0       Everyone
# 32      74819  Varies with device    100,000,000+  Free    0.0       Everyone
# 33      18513                6.1M     10,000,000+  Free    0.0       Everyone
# 34      14552                 17M     10,000,000+  Free    0.0       Everyone
# 35      87055  Varies with device     10,000,000+  Free    0.0       Everyone
# 36      17030  Varies with device     10,000,000+  Free    0.0       Everyone
# 37    1280423  Varies with device    100,000,000+  Free    0.0       Everyone
# 38      25094  Varies with device     10,000,000+  Free    0.0       Everyone
# 39        357                 58M      1,000,000+  Free    0.0       Everyone
# 40        315                4.6M        500,000+  Free    0.0       Everyone
# 41     163997                 16M     10,000,000+  Free    0.0       Everyone
# 42       5431                1.3M     10,000,000+  Free    0.0       Everyone
# 43        124                1.9M        100,000+  Free    0.0       Everyone
# 44       1420                2.7M        100,000+  Free    0.0       Everyone
# 45     118439                 16M     10,000,000+  Free    0.0       Everyone
# 46      59973                 11M     10,000,000+  Free    0.0       Everyone
# 47      32111                5.3M      1,000,000+  Free    0.0       Everyone
# 48     114788  Varies with device      5,000,000+  Free    0.0       Everyone
# 49      70404                4.2M      1,000,000+  Free    0.0       Everyone
# 50     429580  Varies with device     10,000,000+  Free    0.0       Everyone
# 51     876866                9.1M     50,000,000+  Free    0.0       Everyone
# 52     207706                4.3M     10,000,000+  Free    0.0       Everyone
# 53    4254879  Varies with device    100,000,000+  Free    0.0       Everyone
# 54     111507  Varies with device     10,000,000+  Free    0.0       Everyone
# 55     472904  Varies with device     50,000,000+  Free    0.0       Everyone
# 56     115409  Varies with device     10,000,000+  Free    0.0       Everyone
# 57     166367                1.8M      5,000,000+  Free    0.0       Everyone
# 58     618918  Varies with device     50,000,000+  Free    0.0       Everyone
# 59     192661                8.5M     10,000,000+  Free    0.0       Everyone
# 60      54207                4.4M      5,000,000+  Free    0.0       Everyone
# 61      60571  Varies with device      5,000,000+  Free    0.0       Everyone
# 62    1335799                3.8M     50,000,000+  Free    0.0       Everyone
# 63     148506                 11M      5,000,000+  Free    0.0       Everyone
# 64     679912  Varies with device     10,000,000+  Free    0.0       Everyone
# 65     152692                 11M      5,000,000+  Free    0.0       Everyone
# 66      77311  Varies with device      5,000,000+  Free    0.0       Everyone
# 67      48211                7.4M      1,000,000+  Free    0.0       Everyone
# 68      12388                5.3M      1,000,000+  Free    0.0       Everyone
# 69      85387                5.4M      1,000,000+  Free    0.0       Everyone
# 70      33509                3.6M      1,000,000+  Free    0.0       Everyone
# 71     342336  Varies with device     10,000,000+  Free    0.0       Everyone
# 72      90831                4.3M     10,000,000+  Free    0.0       Everyone
# 73      12718  Varies with device      1,000,000+  Free    0.0       Everyone
# 74      85659                 27M      5,000,000+  Free    0.0       Everyone
# 75      16395  Varies with device      1,000,000+  Free    0.0       Everyone
# 76        807                1.8M        100,000+  Free    0.0       Everyone
# 77      24265                3.3M      1,000,000+  Free    0.0       Everyone
# 78       1657                2.0M        100,000+  Free    0.0       Everyone
# 79     576454                6.1M     50,000,000+  Free    0.0       Everyone
# 80      88675                9.6M      5,000,000+  Free    0.0       Everyone
# 81      56848                9.6M      1,000,000+  Free    0.0       Everyone
# 82      19096                 10M      1,000,000+  Free    0.0       Everyone
# 83    1116393                8.2M     50,000,000+  Free    0.0       Everyone
# 84     154578                 14M     10,000,000+  Free    0.0       Everyone
# 85      40676                 25M      1,000,000+  Free    0.0       Everyone
# 86      39833                9.9M      1,000,000+  Free    0.0       Everyone
# ...
# 298                                    3.1.3          4.2 and up
# 299                                   V1.7.6          4.0 and up
# 300                                   2.1.11          4.1 and up
# 301                                   2.5.18          1.6 and up
# 302                                   2.1.15          1.6 and up
# 303                                      4.8          4.1 and up
# 304                                     1.00          7.0 and up
# 305                                     4.72          7.0 and up
# 306  no_update_signal.2_9_1_arm-x86_64-alpha          4.2 and up
# 307                       Varies with device          5.1 and up
# 308                                    2.0.1          1.6 and up
# 309                                    2.3.5        2.3.3 and up
# 310                                      4.0          4.1 and up
# 311                                        2        4.0.3 and up
# 312                                      1.9        4.0.3 and up
# 313                                      1.0          3.0 and up
# 314                                 2.2 Free        4.0.3 and up
# 315                                    1.0.0          4.0 and up
# 316                                    4.7.0          4.1 and up
# 317                                   1.0.70          1.6 and up
# 318                                     3.70          5.0 and up
# 319                                      1.1          1.6 and up
# 320                                      1.3          2.1 and up
# 321                                    1.0.6          4.0 and up
# 322                                      1.1          5.0 and up
# 323                       Varies with device  Varies with device
# 324                       Varies with device  Varies with device
# 325                       Varies with device  Varies with device
# 326                                    4.6.6  Varies with device
# 327                       Varies with device  Varies with device
# 328                                    2.1.4          4.0 and up
# 329                                    1.6.2        4.0.3 and up
# 330                                    1.0.2          2.3 and up
# 331                                    1.4.0          2.3 and up
# 332                                      4.5          4.2 and up
# 333                                    2.0.0          4.0 and up
# 334                                    1.1.0          2.3 and up
# 335                                    1.0.5          4.0 and up
# 336                                     6.24          4.0 and up
# 337                                    1.0.4          2.3 and up
# 338                       Varies with device  Varies with device
# 339                                      1.0          2.2 and up
# 340                                    1.1.6          4.0 and up
# 341                                      2.1          2.2 and up
# 342                                    4.0.4          4.3 and up
# 343                                      1.1          4.0 and up
# 344                                    1.0.9          4.1 and up
# 345                                     3.24          4.1 and up
# 346                                      3.0          1.6 and up
# 347                                    1.0.5  Varies with device
# 348                                  4.1.8.1          4.1 and up
# 349                                   1.13.0          5.0 and up
# 350                                      1.3          4.2 and up
# 351                                    2.4.7          3.0 and up
# 352                                      2.6          4.4 and up
# 353                                    2.51f          5.0 and up
# 354                                      4.2          4.1 and up
# 355                                    1.3.0          4.1 and up
# 356                                    1.4.0          4.1 and up
# 357                                    1.8.0          4.1 and up
# 358                                    1.3.0          4.1 and up
# 359                                      1.0        4.0.3 and up
# 360                                    1.3.0          4.1 and up
# 361                                      2.2          4.0 and up
# 362                                      3.3          3.0 and up
# 363                                  1.0.209          4.0 and up
# 364                                    1.2.0          4.1 and up
# 365                                  1.0.209          4.0 and up
# 366                                    1.2.1          4.1 and up
# 367                                    1.0.5          4.4 and up
# 368                               6.0.932740          2.2 and up
# 369                                      1.5          4.0 and up
# 370                                      2.3        4.0.3 and up
# 371                                    1.0.7          5.0 and up
# 372                                      2.0          2.1 and up
# 373                                    3.2.3          4.2 and up
# 374                             3.2.17030601          2.2 and up
# 375                                     2.95          4.0 and up
# 376                                   2.1.69        4.0.3 and up
# 377                        Translator 10.9.2        4.0.3 and up
# 378                                     4.75        4.0.3 and up
# 379                                    3.0.5          4.4 and up
# 380                       Varies with device  Varies with device
# 381                       Varies with device  Varies with device
# 382                                    1.2.9          4.0 and up
# 383                                      1.6          2.1 and up
# 384                                    3.2.6          2.3 and up
# 385                                     1.08          3.0 and up
# 386                                    1.0.1          4.1 and up
# 387                                      1.1          4.4 and up
# 388                                      1.7          4.0 and up
# 389                                    0.4.1          4.1 and up
# 390                                      1.3        2.3.3 and up
# 391                               2.8.9.1004        4.0.3 and up
# 392                                     1.43          4.0 and up
# 393                                     1.56          1.6 and up
# 394                                    2.1.1          4.1 and up
# 395                                    9.5.8          4.1 and up
# 396                             1.2.1009.695        4.0.3 and up
# 397                       Varies with device  Varies with device
# 398                                   5.42.1          2.3 and up
# 399                                      1.0          4.1 and up
# 400                                      1.0          4.1 and up
# 401                                    6.4.0          4.0 and up
# 402                       Varies with device  Varies with device
# 403                                    2.0.9          4.0 and up
# 404                       Varies with device  Varies with device
# 405                                    2.0.7          4.1 and up
# 406                                 20170828  Varies with device
# 407                                    1.1.6          2.3 and up
# 408                                    1.0.5          2.3 and up
# 409                                     5.19        4.0.3 and up
# 410                                    2.0.7          4.1 and up
# 411                                 12.04.18          3.0 and up
# 412                                     3.48        4.0.3 and up
# 413                                   4.1.9o          4.0 and up
# 414                                   1.0.81          4.1 and up
# 415                                    1.5.2          4.1 and up
# 416                                    2.7.5          4.2 and up
# 417                                    2.3.2          5.0 and up
# 418                                    1.5.2          2.3 and up
# 419                                    4.1.0          4.1 and up
# 420                       Varies with device  Varies with device
# 421                                3.2.0.169          2.3 and up
# 422                                   2.2.82          4.0 and up
# 423                                 3.0.1114          4.1 and up
# 424                       Varies with device  Varies with device
# 425                                 2.0.1077          4.1 and up
# 426                                    2.0.1          5.0 and up
# 427                                   1.12.0          4.1 and up
# 428                                    2.8.0          4.0 and up
# 429                                    1.1.8          4.1 and up
# 430                                      5.1          4.1 and up
# 431                                      5.1          4.1 and up
# 432                                     1.31          2.2 and up
# 433                                  2.2.927          4.1 and up
# 434                                    3.1.2          4.0 and up
# 435                                  4.8.7.8          4.0 and up
# 436                                    3.3.1        4.0.3 and up
# 437                                  1.5.9.9          4.0 and up
# 438                               3.0.0.2071          4.0 and up
# 439                                  1.12.23          4.0 and up
# 440                                    2.0.0          4.0 and up
# 441                                    3.1.3        4.0.3 and up
# 442                       Varies with device  Varies with device
# 443                                    1.3.0        2.3.3 and up
# 444                       Varies with device  Varies with device
# 445                                    1.6.7          2.3 and up
# 446                                    1.7.6          2.2 and up
# 447                                    3.7.1          2.2 and up
# 448                                      1.3          5.0 and up
# 449                       Varies with device  Varies with device
# 450                                      1.0        4.0.3 and up
# 451                                    3.0.2          4.0 and up
# 452                                    6.0.0          5.0 and up
# 453                                   1.22.1          4.4 and up
# 454                                      3.0          4.2 and up
# 455                                    3.0.0          4.1 and up
# 456                                      2.0          1.0 and up
# 457                                      6.0          4.0 and up
# 458                                      6.7          2.3 and up
# 459                                      5.0          4.4 and up
# 460                                     1.15          2.2 and up
# 461                       Varies with device  Varies with device
# 462                                    5.3.9          4.0 and up
# 463                                    2.0.4        4.0.3 and up
# 464                                      4.1          1.5 and up
# 465                       Varies with device          4.1 and up
# 466                             Paid-9.4.1.3          4.1 and up
# 467                       Varies with device  Varies with device
# 468                               1.0.612931          5.0 and up
# 469                                      2.5          4.1 and up
# 470                                  1.1.8.2          2.1 and up
# 471                                    3.1.5          4.0 and up
# 472                                    2.0.7          4.0 and up
# 473                                    2.0.3          2.1 and up
# 474                                    2.0.4          2.0 and up
# 475                                    2.0.7          4.0 and up
# 476                                    5.0.5          4.0 and up
# 477                                      1.4          1.6 and up
# 478                               1.0.612919          5.0 and up
# 479                       Varies with device  Varies with device
# 480                                V1-180703          4.4 and up
# 481                                  v3.7.93          5.0 and up
# 482                       Varies with device  Varies with device
# 483                       Varies with device  Varies with device
# 484                                     1.11        4.0.3 and up
# 485                                     1.10          1.6 and up
# 486                       Varies with device  Varies with device
# 487                                      1.4          1.6 and up
# 488                                      1.3          1.6 and up
# 489                                      1.6          1.6 and up
# 490                                      1.1          1.6 and up
# 491                                    2.3.3          2.1 and up
# 492                                    1.1.6          4.0 and up
# 493                                    4.2.0          2.3 and up
# 494                                    1.3.1        4.0.3 and up
# 495                       Varies with device  Varies with device
# 496                                      4.5          4.3 and up
# 497                                   1.4.13          4.0 and up
# 498                               1.0.606863          5.0 and up
# 499                                      4.7          4.0 and up
# 500                                   23.2.7        4.0.3 and up
# 501                                    1.2.3        4.0.3 and up
# 502                                      1.0          2.3 and up
# 503                                    1.1.9        4.0.3 and up
# 504                                      1.0          3.0 and up
# 505                                      2.4          4.4 and up
# 506                                    1.2.4          1.6 and up
# 507                                    2.1.0          4.1 and up
# 508                                    1.0.6          4.2 and up
# 509                                      5.2          5.0 and up
# 510                                     0.11          6.0 and up
# 511                                  1.9.9.5          5.1 and up
# 512                                    5.0.6          6.0 and up
# 513                                     1.20          4.2 and up
# 514                                    1.0.0          2.1 and up
# 515                                      1.4          1.6 and up
# 516                                    1.2.1          4.1 and up
# 517                                  6.06.14          4.4 and up
# 518                                    0.0.9          2.3 and up
# 519                                    3.2.5          5.0 and up
# 520                                      1.2          4.4 and up
# 521                                   1.0.18        4.0.3 and up
# 522                                    1.8.8          2.1 and up
# 523                                    2.2.4          4.4 and up
# 524                                    3.3.0          4.0 and up
# 525                                      6.6          2.0 and up
# 526                                   0.15.2          6.0 and up
# 527                                    1.2.4          6.0 and up
# 528                                    2.4.1          4.4 and up
# 529                                      5.0          4.0 and up
# 530                            1.03.123.0713        4.0.3 and up
# 531                                      1.6          6.0 and up
# 532                                     1.74          4.1 and up
# 533                                  1.9.734          4.1 and up
# 534                                     6.04          4.4 and up
# 535                               1.0.612928          5.0 and up

# %% [markdown]
# ## That's all folks! Great job!
